# %% [markdown]
# ### Animated barcharts

# %%
import numpy as np
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML
import bar_chart_race as bcr
import warnings
warnings.filterwarnings('ignore')

# %%
# Install bar_chart_race package with either of below commands 
# pip install bar_chart_race
# conda install -c conda-forge bar_chart_race

# %% [markdown]
# DataFrame must contain 'wide' data where:
#
# - Every row represents a single period of time
# - Each column holds the value for a particular category
# - The index contains the time component (optional)

# %%
df = bcr.load_dataset('covid19')

# %%
df.shape
# Out:
# (57, 20)

# %%
df.head(3)
# Out:
#             Belgium  Brazil  Canada   China  France  Germany  India  \
# date
# 2020-02-26      NaN     NaN     NaN  2717.0     2.0      NaN    NaN
# 2020-02-27      NaN     NaN     NaN  2746.0     2.0      NaN    NaN
# 2020-02-28      NaN     NaN     NaN  2790.0     2.0      NaN    NaN
#
#             Indonesia  Iran  Ireland  Italy  Mexico  Netherlands  Portugal  \
# date
# 2020-02-26        NaN  19.0      NaN   12.0     NaN          NaN       NaN
# 2020-02-27        NaN  26.0      NaN   17.0     NaN          NaN       NaN
# 2020-02-28        NaN  34.0      NaN   21.0     NaN          NaN       NaN
#
#             Spain  Sweden  Switzerland  Turkey  USA  United Kingdom
# date
# 2020-02-26    NaN     NaN          NaN     NaN  NaN             NaN
# 2020-02-27    NaN     NaN          NaN     NaN  NaN             NaN
# 2020-02-28    NaN     NaN          NaN     NaN  NaN             NaN

# %%
bcr.bar_chart_race(df=df, filename=r'./data/output/covid19.mp4', title='Covid19')

# %%
bcr_html = bcr.bar_chart_race(df=df, filename=None)

# %%
bcr_html
# Out:
# <video width="962" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr_html_v = bcr.bar_chart_race(df=df, filename=None, orientation='v', n_bars=10)

# %%
bcr_html_v
# Out:
# <video width="914" height="552" controls autoplay loop>
#   <source type="video/mp4" src="...
